# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/yolo_new_custom"
# Out:
# backup	   chart_yolov3_custom.png  custom_data2     custom_weight
# chart.png  converted.zip	    custom_data.zip  darknet

# %%
# import os
# os.listdir("/content/drive/My Drive/yolo_new_custom/custom_data")

# %%
# dir = "/content/drive/My Drive/yolo_new_custom/custom_data"
# img = []
# text = []
# for current_dir, dirs, files in os.walk(dir):
#     for f in files:
#         if f.endswith(".jpg"):
#             image = f
#             img.append(image)
#         if f.endswith(".txt"):
#             t = f
#             text.append(t)
# print(img)

# %%
# %cd /content/drive/My Drive/yolo_new_custom/custom_data

# %%
# c = 0
# for i in img:
#   os.rename(i, str(c)+"."+i.split(".")[-1])
#   c+=1
#   print(i)

# %%
# dir = "/content/drive/My Drive/yolo_new_custom/custom_data"

# text = []
# for current_dir, dirs, files in os.walk(dir):
#   for f in files:
#     if f.endswith(".txt"):
#       t = f
#       text.append(t)
# print(text)

# %%
# %cd /content/drive/My Drive/yolo_new_custom/custom_data
# c = 0
# for i in text:
#   os.rename((i-1), str(c)+"."+(i-1).split(".")[-1])
#   c+=1
#   print(i)

# %%
# !unzip "/content/drive/My Drive/yolo_new_custom/converted.zip" -d "/content/drive/My Drive/yolo_new_custom/custom_data2"

# %%
# !git clone "https://github.com/AlexeyAB/darknet.git" "/content/drive/My Drive/yolo_new_custom/darknet"

# %%
# %cd /content/drive/My Drive/yolo_new_custom/darknet
# Out:
# /content/drive/My Drive/yolo_new_custom/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       results
# build		darknet_images.py	json_mjpeg_streams.sh  scripts
# build.ps1	darknet.py		LICENSE		       src
# build.sh	darknet_video.py	Makefile	       video_yolov3.sh
# cfg		data			net_cam_v3.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		net_cam_v4.sh
# CMakeLists.txt	image_yolov4.sh		README.md

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd /content/drive/My Drive/yolo_new_custom
# Out:
# /content/drive/My Drive/yolo_new_custom

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !python ./custom_data2/create-files-data-and-names.py

# %%
# !python ./custom_data2/creating-train-and-test-txt-files.py

# %%
# %cd /content/drive/My Drive/yolo_new_custom
# Out:
# /content/drive/My Drive/yolo_new_custom

# %%
# !ls
# Out:
# backup	converted.zip  custom_data2  custom_data.zip  custom_weight  darknet

# %%
# !./darknet/darknet detector train custom_data2/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show -mjpeg_port 8090 -map
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 468766, rewritten_bbox = 0.939915 %
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.678976, GIOU: 0.667253), Class: 0.999529, Obj: 0.288180, No Obj: 0.001394, .5R: 1.000000, .75R: 0.000000, count: 3, class_loss = 0.657995, iou_loss = 0.158575, total_loss = 0.816570
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 94 Avg (IOU: 0.598181, GIOU: 0.573046), Class: 0.998459, Obj: 0.278867, No Obj: 0.000333, .5R: 0.666667, .75R: 0.166667, count: 6, class_loss = 0.952397, iou_loss = 1.166067, total_loss = 2.118464
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 106 Avg (IOU: 0.000000, GIOU: 0.000000), Class: 0.000000, Obj: 0.000000, No Obj: 0.000027, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 0.014488, iou_loss = 0.000000, total_loss = 0.014488
#  total_bbox = 468775, rewritten_bbox = 0.939897 %
# ...
